# %% [markdown]
# # Estimació p* i q* a partir d'una latent amb probabilitat uniforme en cas d'empat

# %% [markdown]
# Al notebook anterior (`crear_blueprint.ipynb`) es va construir l’estructura base del problema d’alineació de xarxes, definint el wiring (L_wiring), la xarxa observada (A_test) i la funció d’energia (Hamiltoniana) extretes del repositori del paper, així com diferents procediments de permutació per generar configuracions de referència construïdes reordenant l'observació, permutant etiquetes i fent shuffles; en comptes de mostrejar-les a partir d'un model generatiu.
#
#
# En aquest notebook abordem el problema invers del notebook anterior (`crear_blueprint`).
# Si anteriorment generàvem xarxes amb errors a partir d’unes probabilitats conegudes `p` (creació d’enllaç) i `q` (eliminació d’enllaç), ara l’objectiu és estimar aquests paràmetres a partir d’una xarxa observada amb soroll.

# %% [markdown]
# Objectius del notebook:
# - Definir una Latent L* on el cas d'empat (1-0 o 0-1) es decideixi amb una probabilitat 50/50, en comptes d'escollir 0 directament com en el notebook previ.
# - Inferir nous errors p* (probabilitat de crear un enllaç) i q* (probailitat d'eliminar-ne un) a partir de L* i les observacions de parells de xarxes A_test.
# - Generar parells de xarxes a partir de L*, p* i q* i calcular-ne les energies.
# - Representar en un historigrama.
# - Més endavant, comparar per diferents valors de p i q.

# %% [markdown]
# ### Previ

# %%
import itertools
import pickle
import matplotlib.pyplot as plt
import numpy as np
import math
import random
import os
import time
from numba import jit, njit
from numba.types import bool_, int_, float32
from math import comb
from copy import deepcopy
from tqdm import tqdm
import networkx as nx
import pandas as pd
from collections import defaultdict
from itertools import permutations

# %% [markdown]
# #### Carreguem dades:

# %% [markdown]
# Aquest és el mateix dataset que en el notebook anterior.

# %%
L = np.load("A2_blueprint.npy")
Nx=L.shape[0]
Ny=L.shape[1]

# %% [markdown]
# #### Generacio de xarxes amb els errors p_paper i q_paper

# %% [markdown]
# Volem recuperar les xarxes generades amb els errors `p` i `q` coneguts del notebook anterior.
#
# Apliquem la mateixa funció per generar xarxes a partir de la nostra blueprint i fem servir:
# - `p`: probabilitat de crear un enllaç no existent a la xarxa latent.
# - `q`: probabilitat d’eliminar un enllaç existent de la xarxa latent.

# %%
#defineixo funcio CreateCopies
def CreateCopies(L,q,p,num_networks):
    Nx = len(L) #nombre de nodes 
    A_test = np.zeros((num_networks, Nx, Nx)) #crea un array 3D ple de zeros

    for k in range(num_networks):
    #    A_copy = L.copy() #deep copy de L, però no comparteixen memòria. modificar a.copy no modifica L
        for i in range(Nx):
            for j in range(Nx):
                if L[i,j] == 1:
                    # enllaç existent -> pot ser esborrat
                    if np.random.rand() >= q: #genero aleatori entre 0 i 1
                        A_test[k,i,j] = 1
                else:
                    # posició buida -> pot crear-se un fals
                    if np.random.rand() < p:
                        A_test[k,i,j] = 1
        #A_test[k,:,:] = A_copy #guardo cada xarxa k generada.
        # per cada k (ie per cada xarxa), es comença de zero fent una còpia nova i completa de L.


    #print("Xarxes generades amb p i q del paper:")
    print(A_test.shape)
    
    return A_test

# %%
#variables d'interes

q_paper = 0.15
p_paper = 0.007
num_networks = 2

np.random.seed(11)

for nrep in range(10):
    A_test = CreateCopies(L, q_paper, p_paper, num_networks=2)
# Out:
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)

# %% [markdown]
# ### Funcions d'energia del repo

# %%
n_groups = 1 #considerem que els nodes pertanyen a un únic grup
start_groups = np.zeros(1) #indica on comença cada grup
end_groups = np.zeros(1) + Nx #indica on acaba
size_groups = np.zeros(1) + Nx

start_groups, end_groups, size_groups = start_groups.astype(int), end_groups.astype(int), size_groups.astype(int)

# %% [markdown]
# Aquestes són les funcions d'energia que neccessitarem més endavant.

# %%
@jit(nopython = True)
def hamiltonian_prob(Edges_NoL, Edges_L, overlap_0, overlap_1, alpha, beta):

    A_1 = overlap_1 + alpha #o11 al paper
    B_1 = (Edges_L - overlap_1 + beta) #o10 al paper
    C_1 = Edges_L + alpha + beta #o1 al paper
    
    A_0 = overlap_0 + alpha #o00 al paper
    B_0 = (Edges_NoL - overlap_0 + beta) # o01 al paper
    C_0 = Edges_NoL + alpha + beta # o0 al paper
    
    #  [ math.lgamma(n+1) == log(n!) ]
    H1 = math.lgamma(A_1)+ math.lgamma(B_1) - math.lgamma(C_1) 
    H0 = math.lgamma(A_0)+ math.lgamma(B_0) - math.lgamma(C_0) 
    
    H = -(H1 + H0)
    return H
    
    
@jit(nopython=True)
def overlap_total_prob(L_f, A_f, P_inv_f):
    Nx = L_f.shape[0]
    Ny = L_f.shape[1]
    K = A_f.shape[0]
    
    ovlp_0 = np.zeros((K))
    ovlp_1 = np.zeros((K))
    for k in range(0,K):
        for f in range(0,Ny): 
            for c in range(0,Nx):
                p_f=int(P_inv_f[k,f]) #es tradueix l'index del bliueprint al real de 
                 #(per exemple, si el node 1 de L es el node 5 de A, p_f=5)
                p_c=int(P_inv_f[k,c])  
                valor_L, valor_A = L_f[f,c], A_f[k,p_f,p_c] #compara el valor de L i A a la posició corresponent
                
                ovlp_0[k] = ovlp_0[k] + (1-valor_L)*(1-valor_A )#mira si els zeros coincideixen a L i a A
                ovlp_1[k] = ovlp_1[k] + valor_L*valor_A #mira si els 1s coincideixen a 0 i a  A
                
                
    ovlp_1 = int(sum(ovlp_1))
    ovlp_0 = int(sum(ovlp_0)) #se sumen coincidencies en totes les observacions, resultat global
    return ovlp_0, ovlp_1
#retorna ovlp_0 (nre total de no-enllaços ben predits) i ovlp_1 (nre total d'enllacos ben predits)

@jit(nopython=True) # The blueprint is the average of the observations (taking into account the mapping)  
def L_wiring(A_f, P_inv_f): #enlaces que aparecen en la mayoría de observaciones
    #A_f:  te la forma KxNxNy, on K és el nre de xarxes observades
    Nx = A_f.shape[1]
    Ny = A_f.shape[2]
    K = A_f.shape[0] 
    L_new_f = np.zeros((Nx,Ny))
    
    for i in range(0,Nx):
        for j in range(0,Ny):
            for k in range(0,K):
                #per cada posicio (ij) mira en les K xarxes la posicio que li correspon al blueprint (equivalent segons el mapping)
                p1 = int(P_inv_f[k,i]) # Mapping of the observations
                p2 = int(P_inv_f[k,j]) # Mapping of the observations
                L_new_f[i,j] += A_f[k,p1,p2] #sumo les connexions existents a la posició equivalent en les K xarxes observades
            valor_lnew=1/K* L_new_f[i,j] #fa la mitjana de connexions existents en les K xarxes observades
            L_new_f[i,j] = round( valor_lnew ) #redondeja al valor més proper
            # If valor_lnew = 0, L=0 (we could establish L=1, but it is more probable to not have a connection)
            #L_ij=1--> a la majoria de les k observacions alineades hi ha enllaç aquí
            # L_ij=0--> a la majoria de les k observacions alineades no hi ha enllaç aquí 
    return L_new_f

# %% [markdown]
# ## Definim L_wiring_nova

# %% [markdown]
# Volem definir un wiring que, al comparar parells de xarxes actui de la següent manera:
# - si totes dues tenen enllaç a la posició ij--> Lij=1
# - si cap de les dues té enllaç a la posició ij--> Lij=0
# - en cas d'empat, és a dir, que un tingui un enllaç i l'altre no, la posició Lij té probabilitat r del 50% de tenir un 1.

# %%
#volem fer un wiring que, en cas d'empat, assigni amb probabilitat un 1 o un 0 en comptes de redondejar al valor més proper. 
#poso r=0.5 per assignar amb igual probabilitat un 1 o un 0, però es pot modificar per assignar amb més probabilitat un 1 o un 0.
def L_wiring_nova(A_f, P_inv_f, r=0.5): 
    #A_f:  te la forma KxNxNy, on K és el nre de xarxes observades
    Nx = A_f.shape[1]
    Ny = A_f.shape[2]
    K = A_f.shape[0] 
    L_new_f = np.zeros((Nx,Ny))
    
   
    for i in range(0,Nx):
        for j in range(0,Ny):
            suma = 0
            for k in range(0,K):
                #per cada posicio (ij) mira en les K xarxes la posicio que li correspon al blueprint (equivalent segons el mapping)
                p1 = int(P_inv_f[k,i]) # Mapping of the observations
                p2 = int(P_inv_f[k,j]) # Mapping of the observations
                suma += A_f[k,p1,p2] #sumo les connexions existents a la posició equivalent en les K xarxes observades
            valor_lnew = suma/K #fa la mitjana de connexions existents en les K xarxes observades a una determinada posició (ij)
            
            if suma == K/2: #si les dues sumen 1 (tenim una amb 0 i una amb 1)
                if np.random.rand() < r:
                    L_new_f[i,j] = 1
                else:
                    L_new_f[i,j] = 0
            else:
                L_new_f[i,j] = round(valor_lnew) #si no hi ha empat, valor_lnew=0 o valor_lnew=1
    return L_new_f

# %%
#xarxes observades a partir del blueprint L, amb els valors de p i q del paper


Nx = A_test.shape[1]

Ao_enters = A_test.astype(int) #per tenir les xarxes observades en format enter (0 i 1) i no en format float (0.0 i 1.0)
P_inv_id = np.tile(np.arange(Nx), (A_test.shape[0], 1)) #mapping identitat
L_star = L_wiring_nova(Ao_enters, P_inv_id) #L_star (L*) és el wiring que es fa a partir de les observacions, tenint en compte el mapping identitat (no hi ha permutació)

# %% [markdown]
# ### Càlcul de p* i q*

# %%
#ara estimar p_inf i q_inf a partir de L_star i les observacions A_test

zeros_wiring = 0
uns_wiring = 0

nre_p = 0
nre_q = 0

Nx = L_star.shape[0]

for i in range(Nx):
    for j in range(Nx):

        if L_star[i, j] == 0:
            zeros_wiring += 1

            if A_test[0, i, j] == 1:
                nre_p += 1
            if A_test[1, i, j] == 1:
                nre_p += 1

        else:
            uns_wiring += 1

            if A_test[0, i, j] == 0:
                nre_q += 1
            if A_test[1, i, j] == 0:
                nre_q += 1

p_inf = nre_p / (2 * zeros_wiring)
q_inf = nre_q / (2 * uns_wiring)

print("p_inf:", p_inf)
print("q_inf:", q_inf)
# Out:
# p_inf: 0.00622432595867131
# q_inf: 0.13406940063091483

# %% [markdown]
# ## Generem xarxes amb p_inf i q_inf

# %%
np.random.seed(11)

for nrep in range(10):
    A_test = CreateCopies(L_star, q_inf, p_inf, num_networks=2)

    print('rep', nrep,
          'xarxa 1 diff', np.sum(np.abs(A_test[0] - L_star)))
    print('rep', nrep,
          'xarxa 2 diff', np.sum(np.abs(A_test[1] - L_star)))
    print()
# Out:
# (2, 224, 224)
# rep 0 xarxa 1 diff 620.0
# rep 0 xarxa 2 diff 627.0
#
# (2, 224, 224)
# rep 1 xarxa 1 diff 558.0
# rep 1 xarxa 2 diff 583.0
#
# (2, 224, 224)
# rep 2 xarxa 1 diff 603.0
# rep 2 xarxa 2 diff 602.0
#
# (2, 224, 224)
# rep 3 xarxa 1 diff 632.0
# rep 3 xarxa 2 diff 619.0
#
# (2, 224, 224)
# rep 4 xarxa 1 diff 601.0
# rep 4 xarxa 2 diff 639.0
#
# (2, 224, 224)
# rep 5 xarxa 1 diff 628.0
# rep 5 xarxa 2 diff 589.0
#
# (2, 224, 224)
# rep 6 xarxa 1 diff 579.0
# rep 6 xarxa 2 diff 615.0
#
# (2, 224, 224)
# rep 7 xarxa 1 diff 552.0
# rep 7 xarxa 2 diff 606.0
#
# (2, 224, 224)
# rep 8 xarxa 1 diff 608.0
# rep 8 xarxa 2 diff 637.0
#
# (2, 224, 224)
# rep 9 xarxa 1 diff 463.0
# rep 9 xarxa 2 diff 485.0

# %% [markdown]
# #### Comprovacions

# %%
print(np.all(A_test[0] == A_test[0].T))
for k in range(num_networks):

    FP = np.sum((A_test[k] == 1) & (L_star == 0)) #nombre de falsos positius (A_test té un 1 però L_star té un 0) 
    FN = np.sum((A_test[k] == 0) & (L_star == 1)) #nombre de falsos negatius

    zeros_L = np.sum(L_star == 0)
    ones_L  = np.sum(L_star == 1)

    p_est = FP / zeros_L
    q_est = FN / ones_L

    print(f"Network {k}: p_est={p_est:.4f}  q_est={q_est:.4f}")
# Out:
# False
# Network 0: p_est=0.0032  q_est=0.1397
# Network 1: p_est=0.0037  q_est=0.1384

# %% [markdown]
# El valor de q s'aproxima bastant, no obstant, el de p es bastant diferent. Això segurament es deu a que tenim més zeros que uns.

# %%
diffs = []

for k in range(num_networks):
    diff = np.sum(np.abs(A_test[k] - L_star))
    diffs.append(diff)

mean_diff = np.mean(diffs)

print("mean diff:", mean_diff)

ones_L  = np.sum(L_star == 1)
zeros_L = np.sum(L_star == 0)

expected = q_inf * ones_L + p_inf * zeros_L
print("expected diff:", expected)
# Out:
# mean diff: 474.0
# expected diff: 596.0

# %% [markdown]
# ## Càlcul d'energies

# %%
np.random.seed(111)

# blueprint inferido
L = L_star

num_networks = 2
Nx = L.shape[0]

# generar redes con p_inf q_inf
A_test = CreateCopies(L, q_inf, p_inf, num_networks=num_networks)

print("A_test num 1s :", np.sum(A_test[0]), np.sum(A_test[1]))

Ao_enters = A_test.astype(int)
P_inv_id = np.tile(np.arange(Nx), (num_networks, 1))

print("Aplico L_wiring")
L_nova = L_wiring(Ao_enters, P_inv_id)

print("L_nova num 1s :", np.sum(L_nova), np.sum(L))

print("Aplico overlap_total_prob")
ovlp0_identity, ovlp1_identity = overlap_total_prob(L_nova, Ao_enters, P_inv_id)

print("ovlp0_identity =", ovlp0_identity)
print("ovlp1_identity =", ovlp1_identity)

Nx = L_nova.shape[0]
Edges_L = num_networks * int(L_nova.sum())
Edges_NoL = num_networks * Nx * Nx - Edges_L

alpha = 1.0
beta  = 5.0

print("Aplico hamiltonian_prob")

H_identity = hamiltonian_prob(
    Edges_NoL,
    Edges_L,
    ovlp0_identity,
    ovlp1_identity,
    alpha,
    beta
)

print("H_identity =", H_identity)

print("PAS 1 complet correctament.")
# Out:
# (2, 224, 224)
# A_test num 1s : 2202.0 2212.0
# Aplico L_wiring
# L_nova num 1s : 1655.0 2219.0
# Aplico overlap_total_prob
# ovlp0_identity = 95938
# ovlp1_identity = 3310
# Aplico hamiltonian_prob
# H_identity = 6101.737522467818
# PAS 1 complet correctament.

# %%
n_pairs = 1000
H_pairs = []

for t in range(n_pairs):

    # generar dos observaciones nuevas del blueprint
    A_pair = CreateCopies(L, q_inf, p_inf, num_networks=2)

    Ao_pair = A_pair.astype(int)

    P_inv_id = np.tile(np.arange(Nx), (2,1))

    L_pair = L_wiring(Ao_pair, P_inv_id)

    ovlp0_pair, ovlp1_pair = overlap_total_prob(L_pair, Ao_pair, P_inv_id)

    Nx = L_pair.shape[0]

    Edges_L_pair = 2 * int(L_pair.sum())
    Edges_NoL_pair = 2 * Nx * Nx - Edges_L_pair

    H_pair = hamiltonian_prob(
        Edges_NoL_pair,
        Edges_L_pair,
        ovlp0_pair,
        ovlp1_pair,
        alpha,
        beta
    )

    H_pairs.append(H_pair)

    print(f"Pair {t+1}/{n_pairs} — H = {H_pair:.6f}")
# Out:
# (2, 224, 224)
# Pair 1/1000 — H = 6195.416184
# (2, 224, 224)
# Pair 2/1000 — H = 6248.303882
# (2, 224, 224)
# Pair 3/1000 — H = 6203.643478
# (2, 224, 224)
# Pair 4/1000 — H = 6083.529123
# (2, 224, 224)
# Pair 5/1000 — H = 6119.552977
# (2, 224, 224)
# Pair 6/1000 — H = 6145.753430
# (2, 224, 224)
# Pair 7/1000 — H = 6150.729990
# (2, 224, 224)
# Pair 8/1000 — H = 6123.949323
# (2, 224, 224)
# Pair 9/1000 — H = 6310.752067
# (2, 224, 224)
# Pair 10/1000 — H = 6043.434490
# (2, 224, 224)
# Pair 11/1000 — H = 5943.851107
# (2, 224, 224)
# Pair 12/1000 — H = 5908.250633
# (2, 224, 224)
# Pair 13/1000 — H = 6177.092402
# (2, 224, 224)
# Pair 14/1000 — H = 6119.973593
# (2, 224, 224)
# Pair 15/1000 — H = 6133.361989
# (2, 224, 224)
# Pair 16/1000 — H = 6292.610184
# (2, 224, 224)
# Pair 17/1000 — H = 6110.577041
# (2, 224, 224)
# Pair 18/1000 — H = 5922.302563
# (2, 224, 224)
# Pair 19/1000 — H = 6163.915825
# (2, 224, 224)
# Pair 20/1000 — H = 6074.460086
# (2, 224, 224)
# Pair 21/1000 — H = 6114.995294
# (2, 224, 224)
# Pair 22/1000 — H = 6208.471939
# (2, 224, 224)
# Pair 23/1000 — H = 5949.174537
# (2, 224, 224)
# Pair 24/1000 — H = 6088.052475
# (2, 224, 224)
# Pair 25/1000 — H = 6092.575017
# (2, 224, 224)
# Pair 26/1000 — H = 6212.664341
# (2, 224, 224)
# Pair 27/1000 — H = 6213.891579
# (2, 224, 224)
# Pair 28/1000 — H = 6221.105833
# (2, 224, 224)
# Pair 29/1000 — H = 5935.675626
# (2, 224, 224)
# Pair 30/1000 — H = 6056.827697
# (2, 224, 224)
# Pair 31/1000 — H = 6123.748395
# (2, 224, 224)
# Pair 32/1000 — H = 6047.550632
# (2, 224, 224)
# Pair 33/1000 — H = 6016.603149
# (2, 224, 224)
# Pair 34/1000 — H = 5904.628754
# (2, 224, 224)
# Pair 35/1000 — H = 6181.536901
# (2, 224, 224)
# Pair 36/1000 — H = 6021.198308
# (2, 224, 224)
# Pair 37/1000 — H = 6101.617673
# (2, 224, 224)
# Pair 38/1000 — H = 5763.172689
# (2, 224, 224)
# Pair 39/1000 — H = 5786.555580
# (2, 224, 224)
# Pair 40/1000 — H = 6083.847641
# (2, 224, 224)
# Pair 41/1000 — H = 5948.710640
# (2, 224, 224)
# Pair 42/1000 — H = 6341.558621
# (2, 224, 224)
# Pair 43/1000 — H = 6066.121632
# (2, 224, 224)
# Pair 44/1000 — H = 6204.665495
# (2, 224, 224)
# Pair 45/1000 — H = 6199.530906
# (2, 224, 224)
# Pair 46/1000 — H = 6266.476358
# (2, 224, 224)
# Pair 47/1000 — H = 5939.106983
# (2, 224, 224)
# Pair 48/1000 — H = 5899.612103
# (2, 224, 224)
# Pair 49/1000 — H = 5998.430018
# (2, 224, 224)
# Pair 50/1000 — H = 6177.295901
# (2, 224, 224)
# Pair 51/1000 — H = 6111.176565
# (2, 224, 224)
# Pair 52/1000 — H = 5935.213178
# (2, 224, 224)
# Pair 53/1000 — H = 5822.563076
# (2, 224, 224)
# Pair 54/1000 — H = 6114.634129
# (2, 224, 224)
# Pair 55/1000 — H = 6358.248882
# (2, 224, 224)
# Pair 56/1000 — H = 6145.672461
# (2, 224, 224)
# Pair 57/1000 — H = 6376.110137
# (2, 224, 224)
# Pair 58/1000 — H = 6204.379916
# (2, 224, 224)
# Pair 59/1000 — H = 6029.954191
# (2, 224, 224)
# Pair 60/1000 — H = 6096.736964
# (2, 224, 224)
# Pair 61/1000 — H = 6666.787040
# (2, 224, 224)
# Pair 62/1000 — H = 6257.225990
# (2, 224, 224)
# Pair 63/1000 — H = 6359.688761
# (2, 224, 224)
# Pair 64/1000 — H = 6195.477321
# (2, 224, 224)
# Pair 65/1000 — H = 6190.606927
# (2, 224, 224)
# Pair 66/1000 — H = 6270.093658
# (2, 224, 224)
# Pair 67/1000 — H = 5944.990471
# (2, 224, 224)
# Pair 68/1000 — H = 6191.034889
# (2, 224, 224)
# Pair 69/1000 — H = 5913.018399
# (2, 224, 224)
# Pair 70/1000 — H = 6186.143653
# (2, 224, 224)
# Pair 71/1000 — H = 6204.012070
# (2, 224, 224)
# Pair 72/1000 — H = 6012.046405
# (2, 224, 224)
# Pair 73/1000 — H = 6056.669311
# (2, 224, 224)
# Pair 74/1000 — H = 6123.748395
# (2, 224, 224)
# Pair 75/1000 — H = 6016.603149
# (2, 224, 224)
# Pair 76/1000 — H = 6217.655582
# (2, 224, 224)
# Pair 77/1000 — H = 6204.726630
# (2, 224, 224)
# Pair 78/1000 — H = 6204.420741
# (2, 224, 224)
# Pair 79/1000 — H = 6172.545274
# (2, 224, 224)
# Pair 80/1000 — H = 6069.755253
# (2, 224, 224)
# Pair 81/1000 — H = 5922.072409
# (2, 224, 224)
# Pair 82/1000 — H = 6204.093878
# (2, 224, 224)
# Pair 83/1000 — H = 6257.432944
# (2, 224, 224)
# Pair 84/1000 — H = 6311.044550
# (2, 224, 224)
# Pair 85/1000 — H = 6235.192661
# (2, 224, 224)
# Pair 86/1000 — H = 6016.014229
# (2, 224, 224)
# Pair 87/1000 — H = 6217.819364
# (2, 224, 224)
# Pair 88/1000 — H = 6323.564341
# (2, 224, 224)
# Pair 89/1000 — H = 6235.398433
# (2, 224, 224)
# Pair 90/1000 — H = 6110.496947
# (2, 224, 224)
# Pair 91/1000 — H = 6177.255219
# (2, 224, 224)
# Pair 92/1000 — H = 6100.916929
# (2, 224, 224)
# Pair 93/1000 — H = 6177.397565
# (2, 224, 224)
# Pair 94/1000 — H = 5999.034761
# (2, 224, 224)
# Pair 95/1000 — H = 5944.836436
# (2, 224, 224)
# Pair 96/1000 — H = 5850.181937
# (2, 224, 224)
# Pair 97/1000 — H = 6115.555629
# (2, 224, 224)
# Pair 98/1000 — H = 6150.770385
# (2, 224, 224)
# Pair 99/1000 — H = 6110.416817
# (2, 224, 224)
# Pair 100/1000 — H = 5953.433838
# (2, 224, 224)
# Pair 101/1000 — H = 6221.682105
# (2, 224, 224)
# Pair 102/1000 — H = 6395.067180
# (2, 224, 224)
# Pair 103/1000 — H = 6057.341442
# (2, 224, 224)
# Pair 104/1000 — H = 5962.102648
# (2, 224, 224)
# Pair 105/1000 — H = 6114.794737
# (2, 224, 224)
# Pair 106/1000 — H = 6310.165720
# (2, 224, 224)
# Pair 107/1000 — H = 6332.773279
# (2, 224, 224)
# Pair 108/1000 — H = 6132.335666
# (2, 224, 224)
# Pair 109/1000 — H = 6230.326056
# (2, 224, 224)
# Pair 110/1000 — H = 6186.571225
# (2, 224, 224)
# Pair 111/1000 — H = 6208.553822
# (2, 224, 224)
# Pair 112/1000 — H = 6042.762566
# (2, 224, 224)
# Pair 113/1000 — H = 6297.699345
# (2, 224, 224)
# Pair 114/1000 — H = 6186.143653
# (2, 224, 224)
# Pair 115/1000 — H = 6002.617252
# (2, 224, 224)
# Pair 116/1000 — H = 5940.073429
# (2, 224, 224)
# Pair 117/1000 — H = 5989.582308
# (2, 224, 224)
# Pair 118/1000 — H = 6226.774905
# (2, 224, 224)
# Pair 119/1000 — H = 6007.547572
# (2, 224, 224)
# Pair 120/1000 — H = 5853.729628
# (2, 224, 224)
# Pair 121/1000 — H = 5994.104250
# (2, 224, 224)
# Pair 122/1000 — H = 6230.943509
# (2, 224, 224)
# Pair 123/1000 — H = 6123.486850
# (2, 224, 224)
# Pair 124/1000 — H = 5904.151944
# (2, 224, 224)
# Pair 125/1000 — H = 6110.777114
# (2, 224, 224)
# Pair 126/1000 — H = 6216.978411
# (2, 224, 224)
# Pair 127/1000 — H = 6164.098257
# (2, 224, 224)
# Pair 128/1000 — H = 6336.322840
# (2, 224, 224)
# Pair 129/1000 — H = 5998.547235
# (2, 224, 224)
# Pair 130/1000 — H = 5935.406020
# (2, 224, 224)
# Pair 131/1000 — H = 6203.479424
# (2, 224, 224)
# Pair 132/1000 — H = 6203.909758
# (2, 224, 224)
# Pair 133/1000 — H = 5957.962724
# (2, 224, 224)
# Pair 134/1000 — H = 6186.367746
# (2, 224, 224)
# Pair 135/1000 — H = 6186.123267
# (2, 224, 224)
# Pair 136/1000 — H = 5944.354149
# (2, 224, 224)
# Pair 137/1000 — H = 6274.873198
# (2, 224, 224)
# Pair 138/1000 — H = 6614.890443
# (2, 224, 224)
# Pair 139/1000 — H = 6012.242143
# (2, 224, 224)
# Pair 140/1000 — H = 6119.211734
# (2, 224, 224)
# Pair 141/1000 — H = 6052.713101
# (2, 224, 224)
# Pair 142/1000 — H = 6083.150132
# (2, 224, 224)
# Pair 143/1000 — H = 6150.406504
# (2, 224, 224)
# Pair 144/1000 — H = 5993.967667
# (2, 224, 224)
# Pair 145/1000 — H = 5949.135928
# (2, 224, 224)
# Pair 146/1000 — H = 6034.546917
# (2, 224, 224)
# Pair 147/1000 — H = 5971.524781
# (2, 224, 224)
# Pair 148/1000 — H = 6181.923749
# (2, 224, 224)
# Pair 149/1000 — H = 6141.524176
# (2, 224, 224)
# Pair 150/1000 — H = 5998.722908
# (2, 224, 224)
# Pair 151/1000 — H = 6083.628722
# (2, 224, 224)
# Pair 152/1000 — H = 6185.960097
# (2, 224, 224)
# Pair 153/1000 — H = 6323.753426
# (2, 224, 224)
# Pair 154/1000 — H = 6240.119901
# (2, 224, 224)
# Pair 155/1000 — H = 5962.548884
# (2, 224, 224)
# Pair 156/1000 — H = 6047.689077
# (2, 224, 224)
# Pair 157/1000 — H = 6083.887415
# (2, 224, 224)
# Pair 158/1000 — H = 6047.748377
# (2, 224, 224)
# Pair 159/1000 — H = 6204.481961
# (2, 224, 224)
# Pair 160/1000 — H = 6231.128338
# (2, 224, 224)
# Pair 161/1000 — H = 6007.155792
# (2, 224, 224)
# Pair 162/1000 — H = 5908.939240
# (2, 224, 224)
# Pair 163/1000 — H = 5862.825269
# (2, 224, 224)
# Pair 164/1000 — H = 6394.001851
# (2, 224, 224)
# Pair 165/1000 — H = 6235.542334
# (2, 224, 224)
# Pair 166/1000 — H = 5818.232028
# (2, 224, 224)
# Pair 167/1000 — H = 6141.180584
# (2, 224, 224)
# Pair 168/1000 — H = 5862.977221
# (2, 224, 224)
# Pair 169/1000 — H = 6128.183670
# (2, 224, 224)
# Pair 170/1000 — H = 6305.830619
# (2, 224, 224)
# Pair 171/1000 — H = 6119.693296
# (2, 224, 224)
# Pair 172/1000 — H = 5832.366694
# (2, 224, 224)
# Pair 173/1000 — H = 6039.079827
# (2, 224, 224)
# Pair 174/1000 — H = 6048.162905
# (2, 224, 224)
# Pair 175/1000 — H = 6301.724343
# (2, 224, 224)
# Pair 176/1000 — H = 6199.837254
# (2, 224, 224)
# Pair 177/1000 — H = 6043.355575
# (2, 224, 224)
# Pair 178/1000 — H = 6087.952749
# (2, 224, 224)
# Pair 179/1000 — H = 6092.155492
# (2, 224, 224)
# Pair 180/1000 — H = 6195.436566
# (2, 224, 224)
# Pair 181/1000 — H = 6136.708089
# (2, 224, 224)
# Pair 182/1000 — H = 6199.551346
# (2, 224, 224)
# Pair 183/1000 — H = 5993.752814
# (2, 224, 224)
# Pair 184/1000 — H = 6083.728265
# (2, 224, 224)
# Pair 185/1000 — H = 6292.422206
# (2, 224, 224)
# Pair 186/1000 — H = 6061.455239
# (2, 224, 224)
# Pair 187/1000 — H = 6141.503983
# (2, 224, 224)
# Pair 188/1000 — H = 6078.825665
# (2, 224, 224)
# Pair 189/1000 — H = 5958.831926
# (2, 224, 224)
# Pair 190/1000 — H = 6043.749788
# (2, 224, 224)
# Pair 191/1000 — H = 6279.901077
# (2, 224, 224)
# Pair 192/1000 — H = 6128.284278
# (2, 224, 224)
# Pair 193/1000 — H = 6261.861876
# (2, 224, 224)
# Pair 194/1000 — H = 6167.793864
# (2, 224, 224)
# Pair 195/1000 — H = 6199.755612
# (2, 224, 224)
# Pair 196/1000 — H = 6083.030283
# (2, 224, 224)
# Pair 197/1000 — H = 6257.701636
# (2, 224, 224)
# Pair 198/1000 — H = 5985.078977
# (2, 224, 224)
# Pair 199/1000 — H = 6230.552696
# (2, 224, 224)
# Pair 200/1000 — H = 6034.763213
# (2, 224, 224)
# Pair 201/1000 — H = 5763.525119
# (2, 224, 224)
# Pair 202/1000 — H = 6146.218302
# (2, 224, 224)
# Pair 203/1000 — H = 6087.972698
# (2, 224, 224)
# Pair 204/1000 — H = 6065.467329
# (2, 224, 224)
# Pair 205/1000 — H = 6118.970463
# (2, 224, 224)
# Pair 206/1000 — H = 6292.860531
# (2, 224, 224)
# Pair 207/1000 — H = 5962.471362
# (2, 224, 224)
# Pair 208/1000 — H = 6120.033597
# (2, 224, 224)
# Pair 209/1000 — H = 6217.081173
# (2, 224, 224)
# Pair 210/1000 — H = 6257.908052
# (2, 224, 224)
# Pair 211/1000 — H = 5768.092095
# (2, 224, 224)
# Pair 212/1000 — H = 6186.021303
# (2, 224, 224)
# Pair 213/1000 — H = 6078.845596
# (2, 224, 224)
# Pair 214/1000 — H = 5926.223057
# (2, 224, 224)
# Pair 215/1000 — H = 6235.480676
# (2, 224, 224)
# Pair 216/1000 — H = 6159.427035
# (2, 224, 224)
# Pair 217/1000 — H = 5876.975727
# (2, 224, 224)
# Pair 218/1000 — H = 5953.240228
# (2, 224, 224)
# Pair 219/1000 — H = 6217.450643
# (2, 224, 224)
# Pair 220/1000 — H = 6221.805360
# (2, 224, 224)
# Pair 221/1000 — H = 6060.999427
# (2, 224, 224)
# Pair 222/1000 — H = 6056.788114
# (2, 224, 224)
# Pair 223/1000 — H = 5908.461346
# (2, 224, 224)
# Pair 224/1000 — H = 5949.116620
# (2, 224, 224)
# Pair 225/1000 — H = 5998.390928
# (2, 224, 224)
# Pair 226/1000 — H = 6105.897676
# (2, 224, 224)
# Pair 227/1000 — H = 6061.118450
# (2, 224, 224)
# Pair 228/1000 — H = 6114.513578
# (2, 224, 224)
# Pair 229/1000 — H = 6244.099590
# (2, 224, 224)
# Pair 230/1000 — H = 6163.976657
# (2, 224, 224)
# Pair 231/1000 — H = 6105.536896
# (2, 224, 224)
# Pair 232/1000 — H = 6442.436520
# (2, 224, 224)
# Pair 233/1000 — H = 6266.165528
# (2, 224, 224)
# Pair 234/1000 — H = 6110.296553
# (2, 224, 224)
# Pair 235/1000 — H = 6212.766930
# (2, 224, 224)
# Pair 236/1000 — H = 6186.510206
# (2, 224, 224)
# Pair 237/1000 — H = 6096.416544
# (2, 224, 224)
# Pair 238/1000 — H = 6106.037782
# (2, 224, 224)
# Pair 239/1000 — H = 6137.796218
# (2, 224, 224)
# Pair 240/1000 — H = 6061.415650
# (2, 224, 224)
# Pair 241/1000 — H = 6070.490221
# (2, 224, 224)
# Pair 242/1000 — H = 5940.073429
# (2, 224, 224)
# Pair 243/1000 — H = 6025.242700
# (2, 224, 224)
# Pair 244/1000 — H = 5966.998503
# (2, 224, 224)
# Pair 245/1000 — H = 5948.788045
# (2, 224, 224)
# Pair 246/1000 — H = 6123.486850
# (2, 224, 224)
# Pair 247/1000 — H = 6177.295901
# (2, 224, 224)
# Pair 248/1000 — H = 5890.453568
# (2, 224, 224)
# Pair 249/1000 — H = 6154.471118
# (2, 224, 224)
# Pair 250/1000 — H = 6154.653725
# (2, 224, 224)
# Pair 251/1000 — H = 6128.786459
# (2, 224, 224)
# Pair 252/1000 — H = 6097.216515
# (2, 224, 224)
# Pair 253/1000 — H = 6208.103014
# (2, 224, 224)
# Pair 254/1000 — H = 5949.155233
# (2, 224, 224)
# Pair 255/1000 — H = 6279.859571
# (2, 224, 224)
# Pair 256/1000 — H = 6096.736964
# (2, 224, 224)
# Pair 257/1000 — H = 6172.951854
# (2, 224, 224)
# Pair 258/1000 — H = 6047.847165
# (2, 224, 224)
# Pair 259/1000 — H = 5745.837866
# (2, 224, 224)
# Pair 260/1000 — H = 6140.957915
# (2, 224, 224)
# Pair 261/1000 — H = 5890.243772
# (2, 224, 224)
# Pair 262/1000 — H = 5903.692892
# (2, 224, 224)
# Pair 263/1000 — H = 5989.426335
# (2, 224, 224)
# Pair 264/1000 — H = 6292.714536
# (2, 224, 224)
# Pair 265/1000 — H = 5971.970794
# (2, 224, 224)
# Pair 266/1000 — H = 6119.552977
# (2, 224, 224)
# Pair 267/1000 — H = 6231.128338
# (2, 224, 224)
# Pair 268/1000 — H = 5944.373467
# (2, 224, 224)
# Pair 269/1000 — H = 6172.748678
# (2, 224, 224)
# Pair 270/1000 — H = 6109.714141
# (2, 224, 224)
# Pair 271/1000 — H = 6079.144284
# (2, 224, 224)
# Pair 272/1000 — H = 5935.367469
# (2, 224, 224)
# Pair 273/1000 — H = 6230.902410
# (2, 224, 224)
# Pair 274/1000 — H = 6132.537373
# (2, 224, 224)
# Pair 275/1000 — H = 6087.773099
# (2, 224, 224)
# Pair 276/1000 — H = 6043.533083
# (2, 224, 224)
# Pair 277/1000 — H = 6181.434962
# (2, 224, 224)
# Pair 278/1000 — H = 6016.210759
# (2, 224, 224)
# Pair 279/1000 — H = 6056.788114
# (2, 224, 224)
# Pair 280/1000 — H = 5700.185916
# (2, 224, 224)
# Pair 281/1000 — H = 6093.132822
# (2, 224, 224)
# Pair 282/1000 — H = 6020.687835
# (2, 224, 224)
# Pair 283/1000 — H = 6074.460086
# (2, 224, 224)
# Pair 284/1000 — H = 6190.871976
# (2, 224, 224)
# Pair 285/1000 — H = 6097.615134
# (2, 224, 224)
# Pair 286/1000 — H = 6101.757489
# (2, 224, 224)
# Pair 287/1000 — H = 5809.303869
# (2, 224, 224)
# Pair 288/1000 — H = 6016.524743
# (2, 224, 224)
# Pair 289/1000 — H = 6137.575106
# (2, 224, 224)
# Pair 290/1000 — H = 6128.485323
# (2, 224, 224)
# Pair 291/1000 — H = 5971.097054
# (2, 224, 224)
# Pair 292/1000 — H = 6114.312481
# (2, 224, 224)
# Pair 293/1000 — H = 6186.286290
# (2, 224, 224)
# Pair 294/1000 — H = 6221.311848
# (2, 224, 224)
# Pair 295/1000 — H = 6025.929931
# (2, 224, 224)
# Pair 296/1000 — H = 6208.799247
# (2, 224, 224)
# Pair 297/1000 — H = 6287.999865
# (2, 224, 224)
# Pair 298/1000 — H = 5971.272163
# (2, 224, 224)
# Pair 299/1000 — H = 6345.823343
# (2, 224, 224)
# Pair 300/1000 — H = 6252.837750
# (2, 224, 224)
# Pair 301/1000 — H = 6007.704033
# (2, 224, 224)
# Pair 302/1000 — H = 6442.242137
# (2, 224, 224)
# Pair 303/1000 — H = 6195.028497
# (2, 224, 224)
# Pair 304/1000 — H = 5985.195751
# (2, 224, 224)
# Pair 305/1000 — H = 5980.691414
# (2, 224, 224)
# Pair 306/1000 — H = 6123.486850
# (2, 224, 224)
# Pair 307/1000 — H = 5867.865530
# (2, 224, 224)
# Pair 308/1000 — H = 6222.297543
# (2, 224, 224)
# Pair 309/1000 — H = 6065.745214
# (2, 224, 224)
# Pair 310/1000 — H = 6002.676033
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\UX433\miniconda3\envs\myenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\UX433\AppData\Local\Temp\ipykernel_21584\3187535726.py", line 7, in <module>
#     A_pair = CreateCopies(L, q_inf, p_inf, num_networks=2)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\UX433\AppData\Local\Temp\ipykernel_21584\3532574098.py", line None, in CreateCopies
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\UX433\miniconda3\envs\myenv\Lib\site-packages\IPython\core\interactiveshell.py", line 2194, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\UX433\miniconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py", line 1179, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\UX433\miniconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py", line 1050, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\UX433\miniconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py", line 858, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\UX433\miniconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py", line 770, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\UX433\miniconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py", line 533, in format_record
#     assert isinstance(frame_info.lineno, int)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError

# %%
import matplotlib.pyplot as plt

plt.hist(H_pairs, bins=30, density=True)
plt.axvline(H_identity)

plt.xlabel("Energia H")
plt.ylabel("Densitat")
plt.title("Distribució d'energies (parells de xarxes) i H identitat")

plt.show()
