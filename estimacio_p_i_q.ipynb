# %% [markdown]
# # Estimació p* i q* a partir d'una latent amb probabilitat uniforme en cas d'empat

# %% [markdown]
# Objectius del notebook:
# - Definir una Latent L* on el cas d'empat (1-0 o 0-1) es decideixi amb una probabilitat 50/50, en comptes d'escollir 0 directament com en el notebook previ.
# - Inferir nous errors p* (probabilitat de crear un enllaç) i q* (probailitat d'eliminar-ne un) a partir de L* i les observacions de parells de xarxes A_test.
# - Generar parells de xarxes a partir de L*, p* i q* i calcular-ne les energies.
# - Representar en un historigrama.
# - Més endavant, comparar per diferents valors de p i q.

# %% [markdown]
# ### Previ

# %%
import itertools
import pickle
import matplotlib.pyplot as plt
import numpy as np
import math
import random
import os
import time
from numba import jit, njit
from numba.types import bool_, int_, float32
from math import comb
from copy import deepcopy
from tqdm import tqdm
import networkx as nx
import pandas as pd
from collections import defaultdict
from itertools import permutations

# %% [markdown]
# #### Carreguem dades:

# %%
L = np.load("A2_blueprint.npy")
Nx=L.shape[0]
Ny=L.shape[1]

# %% [markdown]
# #### Generacio de xarxes amb els errors p_paper i q_paper

# %%
#variables d'interes

q_paper = 0.15
p_paper = 0.007
num_networks = 2
#defineixo funcio CreateCopies
def CreateCopies(L,q,p,num_networks):
    Nx = len(L) #nombre de nodes 
    A_test = np.zeros((num_networks, Nx, Nx)) #crea un array 3D ple de zeros

    p = p_paper
    q = q_paper

    for k in range(num_networks):
    #    A_copy = L.copy() #deep copy de L, però no comparteixen memòria. modificar a.copy no modifica L
        for i in range(Nx):
            for j in range(Nx):
                if L[i,j] == 1:
                    # enllaç existent -> pot ser esborrat
                    if np.random.rand() >= q: #genero aleatori entre 0 i 1
                        A_test[k,i,j] = 1
                else:
                    # posició buida -> pot crear-se un fals
                    if np.random.rand() < p:
                        A_test[k,i,j] = 1
        #A_test[k,:,:] = A_copy #guardo cada xarxa k generada.
        # per cada k (ie per cada xarxa), es comença de zero fent una còpia nova i completa de L.


    #print("Xarxes generades amb p i q del paper:")
    print(A_test.shape)
    np.save("synthetic_paper.npy", A_test)
    return A_test

# %%
np.random.seed(11) #hem tret la llavor fixa per tenir variabilitat
for nrep in range(10):
    A_test = CreateCopies(L, q_paper, p_paper, num_networks=2)
    #print('rep',nrep,'xarxa 1',np.sum(np.sum(A_test[0]-L)))
    #print('rep',nrep,'xarxa 2',np.sum(np.sum(A_test[1]-L)))
# Out:
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)
# (2, 224, 224)

# %% [markdown]
# #### Funcions d'energia del repo

# %%
n_groups = 1 #considerem que els nodes pertanyen a un únic grup
start_groups = np.zeros(1) #indica on comença cada grup
end_groups = np.zeros(1) + Nx #indica on acaba
size_groups = np.zeros(1) + Nx

start_groups, end_groups, size_groups = start_groups.astype(int), end_groups.astype(int), size_groups.astype(int)

# %%
@jit(nopython = True)
def hamiltonian_prob(Edges_NoL, Edges_L, overlap_0, overlap_1, alpha, beta):

    A_1 = overlap_1 + alpha #o11 al paper
    B_1 = (Edges_L - overlap_1 + beta) #o10 al paper
    C_1 = Edges_L + alpha + beta #o1 al paper
    
    A_0 = overlap_0 + alpha #o00 al paper
    B_0 = (Edges_NoL - overlap_0 + beta) # o01 al paper
    C_0 = Edges_NoL + alpha + beta # o0 al paper
    
    #  [ math.lgamma(n+1) == log(n!) ]
    H1 = math.lgamma(A_1)+ math.lgamma(B_1) - math.lgamma(C_1) 
    H0 = math.lgamma(A_0)+ math.lgamma(B_0) - math.lgamma(C_0) 
    
    H = -(H1 + H0)
    return H
    
    
@jit(nopython=True)
def overlap_total_prob(L_f, A_f, P_inv_f):
    Nx = L_f.shape[0]
    Ny = L_f.shape[1]
    K = A_f.shape[0]
    
    ovlp_0 = np.zeros((K))
    ovlp_1 = np.zeros((K))
    for k in range(0,K):
        for f in range(0,Ny): 
            for c in range(0,Nx):
                p_f=int(P_inv_f[k,f]) #es tradueix l'index del bliueprint al real de 
                 #(per exemple, si el node 1 de L es el node 5 de A, p_f=5)
                p_c=int(P_inv_f[k,c])  
                valor_L, valor_A = L_f[f,c], A_f[k,p_f,p_c] #compara el valor de L i A a la posició corresponent
                
                ovlp_0[k] = ovlp_0[k] + (1-valor_L)*(1-valor_A )#mira si els zeros coincideixen a L i a A
                ovlp_1[k] = ovlp_1[k] + valor_L*valor_A #mira si els 1s coincideixen a 0 i a  A
                
                
    ovlp_1 = int(sum(ovlp_1))
    ovlp_0 = int(sum(ovlp_0)) #se sumen coincidencies en totes les observacions, resultat global
    return ovlp_0, ovlp_1
#retorna ovlp_0 (nre total de no-enllaços ben predits) i ovlp_1 (nre total d'enllacos ben predits)

@jit(nopython=True) # The blueprint is the average of the observations (taking into account the mapping)  
def L_wiring(A_f, P_inv_f): #enlaces que aparecen en la mayoría de observaciones
    #A_f:  te la forma KxNxNy, on K és el nre de xarxes observades
    Nx = A_f.shape[1]
    Ny = A_f.shape[2]
    K = A_f.shape[0] 
    L_new_f = np.zeros((Nx,Ny))
    
    for i in range(0,Nx):
        for j in range(0,Ny):
            for k in range(0,K):
                #per cada posicio (ij) mira en les K xarxes la posicio que li correspon al blueprint (equivalent segons el mapping)
                p1 = int(P_inv_f[k,i]) # Mapping of the observations
                p2 = int(P_inv_f[k,j]) # Mapping of the observations
                L_new_f[i,j] += A_f[k,p1,p2] #sumo les connexions existents a la posició equivalent en les K xarxes observades
            valor_lnew=1/K* L_new_f[i,j] #fa la mitjana de connexions existents en les K xarxes observades
            L_new_f[i,j] = round( valor_lnew ) #redondeja al valor més proper
            # If valor_lnew = 0, L=0 (we could establish L=1, but it is more probable to not have a connection)
            #L_ij=1--> a la majoria de les k observacions alineades hi ha enllaç aquí
            # L_ij=0--> a la majoria de les k observacions alineades no hi ha enllaç aquí 
    return L_new_f

# %% [markdown]
# ## Definim L_wiring_nova

# %%
#volem fer un wiring que, en cas d'empat, assigni amb probabilitat un 1 o un 0 en comptes de redondejar al valor més proper. 
#poso r=0.5 per assignar amb igual probabilitat un 1 o un 0, però es pot modificar per assignar amb més probabilitat un 1 o un 0.
def L_wiring_nova(A_f, P_inv_f, r=0.5): 
    #A_f:  te la forma KxNxNy, on K és el nre de xarxes observades
    Nx = A_f.shape[1]
    Ny = A_f.shape[2]
    K = A_f.shape[0] 
    L_new_f = np.zeros((Nx,Ny))
    
   
    for i in range(0,Nx):
        for j in range(0,Ny):
            suma = 0
            for k in range(0,K):
                #per cada posicio (ij) mira en les K xarxes la posicio que li correspon al blueprint (equivalent segons el mapping)
                p1 = int(P_inv_f[k,i]) # Mapping of the observations
                p2 = int(P_inv_f[k,j]) # Mapping of the observations
                suma += A_f[k,p1,p2] #sumo les connexions existents a la posició equivalent en les K xarxes observades
            valor_lnew = suma/K #fa la mitjana de connexions existents en les K xarxes observades
            
            if suma == K/2: #si les dues sumen 1 (tenim una amb 0 i una amb 1)
                if np.random.rand() < r:
                    L_new_f[i,j] = 1
                else:
                    L_new_f[i,j] = 0
            else:
                L_new_f[i,j] = round(valor_lnew) #si no hi ha empat, valor_lnew=0 o valor_lnew=1
    return L_new_f

# %%
A_test = CreateCopies(L, q_paper, p_paper, num_networks=2)

Nx = A_test.shape[1]

Ao_enters = A_test.astype(int)
P_inv_id = np.tile(np.arange(Nx), (A_test.shape[0], 1))

L_star = L_wiring_nova(Ao_enters, P_inv_id)
# Out:
# (2, 224, 224)

# %%
zeros_wiring = 0
uns_wiring = 0

nre_p = 0
nre_q = 0

Nx = L_star.shape[0]

for i in range(Nx):
    for j in range(Nx):

        if L_star[i, j] == 0:
            zeros_wiring += 1

            if A_test[0, i, j] == 1:
                nre_p += 1
            if A_test[1, i, j] == 1:
                nre_p += 1

        else:
            uns_wiring += 1

            if A_test[0, i, j] == 0:
                nre_q += 1
            if A_test[1, i, j] == 0:
                nre_q += 1

p_inf = nre_p / (2 * zeros_wiring)
q_inf = nre_q / (2 * uns_wiring)

print("p_inf:", p_inf)
print("q_inf:", q_inf)
# Out:
# p_inf: 0.005878306547432931
# q_inf: 0.1398093508851566

# %% [markdown]
# ## Generem xarxes amb p i q

# %%
#variables d'interes
num_networks = 2
#defineixo funcio CreateCopies
def CreateCopies(L,q,p,num_networks):
    Nx = len(L) #nombre de nodes 
    A_test = np.zeros((num_networks, Nx, Nx)) #crea un array 3D ple de zeros


    for k in range(num_networks):
        for i in range(Nx):
            for j in range(Nx):
                if L[i,j] == 1:
                    # enllaç existent -> pot ser esborrat
                    if np.random.rand() >= q: #genero aleatori entre 0 i 1
                        A_test[k,i,j] = 1
                else:
                    # posició buida -> pot crear-se un fals
                    if np.random.rand() < p:
                        A_test[k,i,j] = 1
        
    print(A_test.shape)
    return A_test

# %%
np.random.seed(11)

num_networks = 2

for nrep in range(10):

    A_test = CreateCopies(L_star, q_inf, p_inf, num_networks)

    print('rep', nrep,
          'xarxa 1 diff', np.sum(np.abs(A_test[0] - L_star)))
    print('rep', nrep,
          'xarxa 2 diff', np.sum(np.abs(A_test[1] - L_star)))
    print()

    #print(np.all(A_test[0] == A_test[0].T))
# Out:
# (2, 224, 224)
# rep 0 xarxa 1 diff 695.0
# rep 0 xarxa 2 diff 706.0
#
# (2, 224, 224)
# rep 1 xarxa 1 diff 647.0
# rep 1 xarxa 2 diff 668.0
#
# (2, 224, 224)
# rep 2 xarxa 1 diff 661.0
# rep 2 xarxa 2 diff 675.0
#
# (2, 224, 224)
# rep 3 xarxa 1 diff 694.0
# rep 3 xarxa 2 diff 685.0
#
# (2, 224, 224)
# rep 4 xarxa 1 diff 689.0
# rep 4 xarxa 2 diff 692.0
#
# (2, 224, 224)
# rep 5 xarxa 1 diff 720.0
# rep 5 xarxa 2 diff 660.0
#
# (2, 224, 224)
# rep 6 xarxa 1 diff 665.0
# rep 6 xarxa 2 diff 672.0
#
# (2, 224, 224)
# rep 7 xarxa 1 diff 626.0
# rep 7 xarxa 2 diff 688.0
#
# (2, 224, 224)
# rep 8 xarxa 1 diff 680.0
# rep 8 xarxa 2 diff 709.0
#
# (2, 224, 224)
# rep 9 xarxa 1 diff 644.0
# rep 9 xarxa 2 diff 665.0

# %% [markdown]
# #### Comprovacions

# %%
print(np.all(A_test[0] == A_test[0].T))
for k in range(num_networks):

    FP = np.sum((A_test[k] == 1) & (L_star == 0))
    FN = np.sum((A_test[k] == 0) & (L_star == 1))

    zeros_L = np.sum(L_star == 0)
    ones_L  = np.sum(L_star == 1)

    p_est = FP / zeros_L
    q_est = FN / ones_L

    print(f"Network {k}: p_est={p_est:.4f}  q_est={q_est:.4f}")
# Out:
# False
# Network 0: p_est=0.0070  q_est=0.1403
# Network 1: p_est=0.0073  q_est=0.1421

# %%
diff = np.sum(np.abs(A_test[k] - L_star))
print("diff:", diff)

ones_L  = np.sum(L_star == 1)
zeros_L = np.sum(L_star == 0)

expected = q_inf * ones_L + p_inf * zeros_L
print("expected diff:", expected)
# Out:
# diff: 665.0
# expected diff: 590.0

# %% [markdown]
# ## Càlcul d'energies

# %%
np.random.seed(111)

# blueprint inferido
L = L_star

num_networks = 2
Nx = L.shape[0]

# generar redes con p_inf q_inf
A_test = CreateCopies(L, q_inf, p_inf, num_networks=num_networks)

print("A_test num 1s :", np.sum(A_test[0]), np.sum(A_test[1]))

Ao_enters = A_test.astype(int)
P_inv_id = np.tile(np.arange(Nx), (num_networks, 1))

print("Aplico L_wiring")
L_nova = L_wiring(Ao_enters, P_inv_id)

print("L_nova num 1s :", np.sum(L_nova), np.sum(L))

print("Aplico overlap_total_prob")
ovlp0_identity, ovlp1_identity = overlap_total_prob(L_nova, Ao_enters, P_inv_id)

print("ovlp0_identity =", ovlp0_identity)
print("ovlp1_identity =", ovlp1_identity)

Nx = L_nova.shape[0]
Edges_L = num_networks * int(L_nova.sum())
Edges_NoL = num_networks * Nx * Nx - Edges_L

alpha = 1.0
beta  = 5.0

print("Aplico hamiltonian_prob")

H_identity = hamiltonian_prob(
    Edges_NoL,
    Edges_L,
    ovlp0_identity,
    ovlp1_identity,
    alpha,
    beta
)

print("H_identity =", H_identity)

print("PAS 1 complet correctament.")
# Out:
# (2, 224, 224)
# A_test num 1s : 2182.0 2215.0
# Aplico L_wiring
# L_nova num 1s : 1578.0 2203.0
# Aplico overlap_total_prob
# ovlp0_identity = 95955
# ovlp1_identity = 3156
# Aplico hamiltonian_prob
# H_identity = 6706.368689725659
# PAS 1 complet correctament.

# %%
n_shuffles = 1000
H_shuffle = []

for t in range(n_shuffles):
    # Generar P_inv aleatori
    P_inv_shuffle = np.array([np.random.permutation(Nx) for _ in range(num_networks)], dtype=np.int64)
    #fem servir random permutations enlloc de shuffle perque shuffle modifica l'array original
    # mateix pipeline que per P_inv_id
    L_sh = L_wiring(Ao_enters, P_inv_shuffle)
    ovlp0_sh, ovlp1_sh = overlap_total_prob(L_sh, Ao_enters, P_inv_shuffle)
    print("ovlp0_sh =", ovlp0_sh, " ovlp1_sh =", ovlp1_sh)
    Nx = L_sh.shape[0]
    Edges_L_sh = num_networks* int(L_sh.sum()) # nombre de 1s de la blueprint
    Edges_NoL_sh = num_networks*Nx*Nx - Edges_L_sh    # nombre de 0s
    H_sh = hamiltonian_prob(Edges_NoL_sh,  Edges_L_sh, ovlp0_sh, ovlp1_sh, alpha, beta)

    H_shuffle.append(H_sh) #guardar valors
    print(f"Shuffle {t+1}/{n_shuffles}  —  H = {H_sh:.6f}")

print("H_identity =", H_identity)
print("H_shuffle (lista) =", H_shuffle)
np.save("H_shuffle.npy", np.array(H_shuffle))
# Out:
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 1/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 2/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 3/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 4/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 230
# Shuffle 5/1000  —  H = 17369.995825
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 6/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 7/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 8/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 9/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 10/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 11/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 12/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 13/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 162
# Shuffle 14/1000  —  H = 17583.857575
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 15/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 16/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 17/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 18/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 230
# Shuffle 19/1000  —  H = 17369.995825
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 20/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 21/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 22/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 23/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 24/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 25/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 26/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 27/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 28/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 29/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 238
# Shuffle 30/1000  —  H = 17344.731917
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 31/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 32/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 33/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 34/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 35/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 228
# Shuffle 36/1000  —  H = 17376.308597
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 37/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 140
# Shuffle 38/1000  —  H = 17652.666356
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 39/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 40/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 41/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 42/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 43/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 218
# Shuffle 44/1000  —  H = 17407.852936
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 45/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 154
# Shuffle 46/1000  —  H = 17608.903257
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 47/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 48/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 49/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 50/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 51/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 52/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 53/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 54/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 55/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 56/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 166
# Shuffle 57/1000  —  H = 17571.324830
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 58/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 59/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 60/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 61/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 62/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 63/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 160
# Shuffle 64/1000  —  H = 17590.121498
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 65/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 66/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 152
# Shuffle 67/1000  —  H = 17615.160442
# ovlp0_sh = 95955  ovlp1_sh = 240
# Shuffle 68/1000  —  H = 17338.412764
# ovlp0_sh = 95955  ovlp1_sh = 162
# Shuffle 69/1000  —  H = 17583.857575
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 70/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 71/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 72/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 73/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 74/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 75/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 158
# Shuffle 76/1000  —  H = 17596.383765
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 77/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 78/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 79/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 80/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 81/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 166
# Shuffle 82/1000  —  H = 17571.324830
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 83/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 84/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 85/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 86/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 226
# Shuffle 87/1000  —  H = 17382.620077
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 88/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 89/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 90/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 91/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 92/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 93/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 94/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 95/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 96/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 97/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 226
# Shuffle 98/1000  —  H = 17382.620077
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 99/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 100/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 101/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 102/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 103/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 104/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 152
# Shuffle 105/1000  —  H = 17615.160442
# ovlp0_sh = 95955  ovlp1_sh = 232
# Shuffle 106/1000  —  H = 17363.681765
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 107/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 108/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 109/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 110/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 111/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 112/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 244
# Shuffle 113/1000  —  H = 17325.770682
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 114/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 115/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 116/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 117/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 150
# Shuffle 118/1000  —  H = 17621.415894
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 119/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 120/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 121/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 122/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 123/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 162
# Shuffle 124/1000  —  H = 17583.857575
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 125/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 220
# Shuffle 126/1000  —  H = 17401.546693
# ovlp0_sh = 95955  ovlp1_sh = 228
# Shuffle 127/1000  —  H = 17376.308597
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 128/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 129/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 130/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 131/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 132/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 133/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 134/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 135/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 136/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 137/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 224
# Shuffle 138/1000  —  H = 17388.930257
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 139/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 140/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 218
# Shuffle 141/1000  —  H = 17407.852936
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 142/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 162
# Shuffle 143/1000  —  H = 17583.857575
# ovlp0_sh = 95955  ovlp1_sh = 158
# Shuffle 144/1000  —  H = 17596.383765
# ovlp0_sh = 95955  ovlp1_sh = 220
# Shuffle 145/1000  —  H = 17401.546693
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 146/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 147/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 148/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 149/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 150/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 151/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 152/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 153/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 154/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 155/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 158
# Shuffle 156/1000  —  H = 17596.383765
# ovlp0_sh = 95955  ovlp1_sh = 146
# Shuffle 157/1000  —  H = 17633.921507
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 158/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 228
# Shuffle 159/1000  —  H = 17376.308597
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 160/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 228
# Shuffle 161/1000  —  H = 17376.308597
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 162/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 236
# Shuffle 163/1000  —  H = 17351.049805
# ovlp0_sh = 95955  ovlp1_sh = 144
# Shuffle 164/1000  —  H = 17640.171624
# ovlp0_sh = 95955  ovlp1_sh = 162
# Shuffle 165/1000  —  H = 17583.857575
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 166/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 167/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 168/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 169/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 170/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 171/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 172/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 232
# Shuffle 173/1000  —  H = 17363.681765
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 174/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 175/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 176/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 177/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 220
# Shuffle 178/1000  —  H = 17401.546693
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 179/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 180/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 181/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 182/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 183/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 230
# Shuffle 184/1000  —  H = 17369.995825
# ovlp0_sh = 95955  ovlp1_sh = 218
# Shuffle 185/1000  —  H = 17407.852936
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 186/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 224
# Shuffle 187/1000  —  H = 17388.930257
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 188/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 189/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 190/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 230
# Shuffle 191/1000  —  H = 17369.995825
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 192/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 193/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 194/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 195/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 196/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 197/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 198/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 199/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 200/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 201/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 202/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 203/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 204/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 205/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 206/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 207/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 208/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 209/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 210/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 211/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 212/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 213/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 214/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 215/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 216/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 217/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 158
# Shuffle 218/1000  —  H = 17596.383765
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 219/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 220/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 221/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 222/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 223/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 224/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 225/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 226/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 227/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 228/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 229/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 230/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 231/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 232/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 230
# Shuffle 233/1000  —  H = 17369.995825
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 234/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 235/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 236
# Shuffle 236/1000  —  H = 17351.049805
# ovlp0_sh = 95955  ovlp1_sh = 218
# Shuffle 237/1000  —  H = 17407.852936
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 238/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 239/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 240/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 241/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 242/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 243/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 244/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 245/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 246/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 247/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 248/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 249/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 250/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 251/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 252/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 253/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 166
# Shuffle 254/1000  —  H = 17571.324830
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 255/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 166
# Shuffle 256/1000  —  H = 17571.324830
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 257/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 258/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 259/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 260/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 261/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 236
# Shuffle 262/1000  —  H = 17351.049805
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 263/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 264/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 265/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 266/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 267/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 268/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 220
# Shuffle 269/1000  —  H = 17401.546693
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 270/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 271/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 272/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 224
# Shuffle 273/1000  —  H = 17388.930257
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 274/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 275/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 276/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 277/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 278/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 279/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 154
# Shuffle 280/1000  —  H = 17608.903257
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 281/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 282/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 218
# Shuffle 283/1000  —  H = 17407.852936
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 284/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 285/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 234
# Shuffle 286/1000  —  H = 17357.366423
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 287/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 288/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 289/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 290/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 291/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 292/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 293/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 294/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 148
# Shuffle 295/1000  —  H = 17627.669589
# ovlp0_sh = 95955  ovlp1_sh = 246
# Shuffle 296/1000  —  H = 17319.447764
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 297/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 298/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 299/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 300/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 301/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 302/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 303/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 304/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 305/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 306/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 307/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 308/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 309/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 310/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 240
# Shuffle 311/1000  —  H = 17338.412764
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 312/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 313/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 314/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 315/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 316/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 317/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 318/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 319/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 320/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 321/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 322/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 323/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 324/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 325/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 326/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 327/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 328/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 329/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 330/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 331/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 160
# Shuffle 332/1000  —  H = 17590.121498
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 333/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 334/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 335/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 336/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 337/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 338/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 339/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 228
# Shuffle 340/1000  —  H = 17376.308597
# ovlp0_sh = 95955  ovlp1_sh = 162
# Shuffle 341/1000  —  H = 17583.857575
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 342/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 343/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 344/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 345/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 230
# Shuffle 346/1000  —  H = 17369.995825
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 347/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 348/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 349/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 218
# Shuffle 350/1000  —  H = 17407.852936
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 351/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 220
# Shuffle 352/1000  —  H = 17401.546693
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 353/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 354/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 355/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 356/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 230
# Shuffle 357/1000  —  H = 17369.995825
# ovlp0_sh = 95955  ovlp1_sh = 226
# Shuffle 358/1000  —  H = 17382.620077
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 359/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 360/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 361/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 362/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 244
# Shuffle 363/1000  —  H = 17325.770682
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 364/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 365/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 366/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 367/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 368/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 369/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 370/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 371/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 372/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 373/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 374/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 375/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 376/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 377/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 378/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 379/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 380/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 381/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 382/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 150
# Shuffle 383/1000  —  H = 17621.415894
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 384/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 385/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 386/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 387/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 388/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 389/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 390/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 391/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 244
# Shuffle 392/1000  —  H = 17325.770682
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 393/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 394/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 395/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 162
# Shuffle 396/1000  —  H = 17583.857575
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 397/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 398/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 399/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 226
# Shuffle 400/1000  —  H = 17382.620077
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 401/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 158
# Shuffle 402/1000  —  H = 17596.383765
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 403/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 218
# Shuffle 404/1000  —  H = 17407.852936
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 405/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 406/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 160
# Shuffle 407/1000  —  H = 17590.121498
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 408/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 409/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 410/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 411/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 412/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 413/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 414/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 244
# Shuffle 415/1000  —  H = 17325.770682
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 416/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 417/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 418/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 419/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 420/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 421/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 422/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 423/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 424/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 425/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 426/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 226
# Shuffle 427/1000  —  H = 17382.620077
# ovlp0_sh = 95955  ovlp1_sh = 232
# Shuffle 428/1000  —  H = 17363.681765
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 429/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 430/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 431/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 432/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 433/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 166
# Shuffle 434/1000  —  H = 17571.324830
# ovlp0_sh = 95955  ovlp1_sh = 152
# Shuffle 435/1000  —  H = 17615.160442
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 436/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 437/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 438/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 156
# Shuffle 439/1000  —  H = 17602.644358
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 440/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 441/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 442/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 443/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 224
# Shuffle 444/1000  —  H = 17388.930257
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 445/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 446/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 447/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 448/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 449/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 450/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 451/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 218
# Shuffle 452/1000  —  H = 17407.852936
# ovlp0_sh = 95955  ovlp1_sh = 160
# Shuffle 453/1000  —  H = 17590.121498
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 454/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 455/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 456/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 457/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 458/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 162
# Shuffle 459/1000  —  H = 17583.857575
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 460/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 228
# Shuffle 461/1000  —  H = 17376.308597
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 462/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 463/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 464/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 465/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 466/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 467/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 468/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 469/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 470/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 471/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 472/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 473/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 474/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 475/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 160
# Shuffle 476/1000  —  H = 17590.121498
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 477/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 478/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 152
# Shuffle 479/1000  —  H = 17615.160442
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 480/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 481/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 482/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 483/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 484/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 485/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 486/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 487/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 488/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 489/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 246
# Shuffle 490/1000  —  H = 17319.447764
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 491/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 492/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 493/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 494/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 495/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 496/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 497/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 498/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 499/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 500/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 501/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 502/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 166
# Shuffle 503/1000  —  H = 17571.324830
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 504/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 505/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 220
# Shuffle 506/1000  —  H = 17401.546693
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 507/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 508/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 509/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 510/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 511/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 512/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 513/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 514/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 515/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 516/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 517/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 518/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 166
# Shuffle 519/1000  —  H = 17571.324830
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 520/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 226
# Shuffle 521/1000  —  H = 17382.620077
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 522/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 523/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 524/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 525/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 526/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 527/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 528/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 236
# Shuffle 529/1000  —  H = 17351.049805
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 530/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 531/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 532/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 533/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 534/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 535/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 536/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 537/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 538/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 539/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 540/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 541/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 542/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 543/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 166
# Shuffle 544/1000  —  H = 17571.324830
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 545/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 546/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 158
# Shuffle 547/1000  —  H = 17596.383765
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 548/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 549/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 550/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 551/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 552/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 553/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 554/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 555/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 556/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 557/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 162
# Shuffle 558/1000  —  H = 17583.857575
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 559/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 560/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 561/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 562/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 563/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 564/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 565/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 566/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 567/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 166
# Shuffle 568/1000  —  H = 17571.324830
# ovlp0_sh = 95955  ovlp1_sh = 152
# Shuffle 569/1000  —  H = 17615.160442
# ovlp0_sh = 95955  ovlp1_sh = 226
# Shuffle 570/1000  —  H = 17382.620077
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 571/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 572/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 573/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 574/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 232
# Shuffle 575/1000  —  H = 17363.681765
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 576/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 577/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 578/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 579/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 580/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 581/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 582/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 583/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 584/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 585/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 586/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 238
# Shuffle 587/1000  —  H = 17344.731917
# ovlp0_sh = 95955  ovlp1_sh = 166
# Shuffle 588/1000  —  H = 17571.324830
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 589/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 590/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 591/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 592/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 593/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 594/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 224
# Shuffle 595/1000  —  H = 17388.930257
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 596/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 597/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 598/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 599/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 600/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 601/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 602/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 603/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 158
# Shuffle 604/1000  —  H = 17596.383765
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 605/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 606/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 607/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 608/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 609/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 610/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 611/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 612/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 158
# Shuffle 613/1000  —  H = 17596.383765
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 614/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 615/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 616/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 617/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 618/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 619/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 620/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 621/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 622/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 623/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 624/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 625/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 626/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 627/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 628/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 629/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 630/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 160
# Shuffle 631/1000  —  H = 17590.121498
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 632/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 633/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 634/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 635/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 636/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 637/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 638/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 639/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 640/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 641/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 642/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 226
# Shuffle 643/1000  —  H = 17382.620077
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 644/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 645/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 646/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 647/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 146
# Shuffle 648/1000  —  H = 17633.921507
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 649/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 650/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 651/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 240
# Shuffle 652/1000  —  H = 17338.412764
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 653/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 654/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 162
# Shuffle 655/1000  —  H = 17583.857575
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 656/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 657/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 658/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 659/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 660/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 661/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 662/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 663/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 664/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 220
# Shuffle 665/1000  —  H = 17401.546693
# ovlp0_sh = 95955  ovlp1_sh = 256
# Shuffle 666/1000  —  H = 17287.814586
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 667/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 668/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 226
# Shuffle 669/1000  —  H = 17382.620077
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 670/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 671/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 672/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 673/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 674/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 675/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 166
# Shuffle 676/1000  —  H = 17571.324830
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 677/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 214
# ...
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 833/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 834/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 835/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 836/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 837/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 838/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 839/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 840/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 841/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 842/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 843/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 844/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 845/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 846/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 156
# Shuffle 847/1000  —  H = 17602.644358
# ovlp0_sh = 95955  ovlp1_sh = 218
# Shuffle 848/1000  —  H = 17407.852936
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 849/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 850/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 218
# Shuffle 851/1000  —  H = 17407.852936
# ovlp0_sh = 95955  ovlp1_sh = 224
# Shuffle 852/1000  —  H = 17388.930257
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 853/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 224
# Shuffle 854/1000  —  H = 17388.930257
# ovlp0_sh = 95955  ovlp1_sh = 220
# Shuffle 855/1000  —  H = 17401.546693
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 856/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 248
# Shuffle 857/1000  —  H = 17313.123601
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 858/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 158
# Shuffle 859/1000  —  H = 17596.383765
# ovlp0_sh = 95955  ovlp1_sh = 226
# Shuffle 860/1000  —  H = 17382.620077
# ovlp0_sh = 95955  ovlp1_sh = 162
# Shuffle 861/1000  —  H = 17583.857575
# ovlp0_sh = 95955  ovlp1_sh = 240
# Shuffle 862/1000  —  H = 17338.412764
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 863/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 864/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 865/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 866/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 218
# Shuffle 867/1000  —  H = 17407.852936
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 868/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 869/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 870/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 150
# Shuffle 871/1000  —  H = 17621.415894
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 872/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 873/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 874/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 875/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 876/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 877/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 878/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 879/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 880/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 881/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 160
# Shuffle 882/1000  —  H = 17590.121498
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 883/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 884/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 885/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 886/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 887/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 888/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 889/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 890/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 891/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 892/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 230
# Shuffle 893/1000  —  H = 17369.995825
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 894/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 895/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 896/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 897/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 898/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 899/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 900/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 901/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 902/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 218
# Shuffle 903/1000  —  H = 17407.852936
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 904/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 905/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 906/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 907/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 908/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 226
# Shuffle 909/1000  —  H = 17382.620077
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 910/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 911/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 912/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 913/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 914/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 915/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 916/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 917/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 918/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 919/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 920/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 921/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 922/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 923/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 924/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 925/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 926/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 927/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 162
# Shuffle 928/1000  —  H = 17583.857575
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 929/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 930/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 931/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 932/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 933/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 934/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 935/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 216
# Shuffle 936/1000  —  H = 17414.157853
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 937/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 938/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 939/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 940/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 941/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 186
# Shuffle 942/1000  —  H = 17508.567169
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 943/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 944/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 945/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 236
# Shuffle 946/1000  —  H = 17351.049805
# ovlp0_sh = 95955  ovlp1_sh = 176
# Shuffle 947/1000  —  H = 17539.965149
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 948/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 949/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 950/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 220
# Shuffle 951/1000  —  H = 17401.546693
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 952/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 184
# Shuffle 953/1000  —  H = 17514.849751
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 954/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 955/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 164
# Shuffle 956/1000  —  H = 17577.592013
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 957/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 250
# Shuffle 958/1000  —  H = 17306.798197
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 959/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 960/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 202
# Shuffle 961/1000  —  H = 17458.254532
# ovlp0_sh = 95955  ovlp1_sh = 170
# Shuffle 962/1000  —  H = 17558.785665
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 963/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 964/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 204
# Shuffle 965/1000  —  H = 17451.959105
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 966/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 196
# Shuffle 967/1000  —  H = 17477.132445
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 968/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 168
# Shuffle 969/1000  —  H = 17565.056042
# ovlp0_sh = 95955  ovlp1_sh = 156
# Shuffle 970/1000  —  H = 17602.644358
# ovlp0_sh = 95955  ovlp1_sh = 148
# Shuffle 971/1000  —  H = 17627.669589
# ovlp0_sh = 95955  ovlp1_sh = 200
# Shuffle 972/1000  —  H = 17464.548570
# ovlp0_sh = 95955  ovlp1_sh = 208
# Shuffle 973/1000  —  H = 17439.364120
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 974/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 214
# Shuffle 975/1000  —  H = 17420.461437
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 976/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 198
# Shuffle 977/1000  —  H = 17470.841211
# ovlp0_sh = 95955  ovlp1_sh = 166
# Shuffle 978/1000  —  H = 17571.324830
# ovlp0_sh = 95955  ovlp1_sh = 220
# Shuffle 979/1000  —  H = 17401.546693
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 980/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 981/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 982/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 983/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 178
# Shuffle 984/1000  —  H = 17533.688564
# ovlp0_sh = 95955  ovlp1_sh = 210
# Shuffle 985/1000  —  H = 17433.064578
# ovlp0_sh = 95955  ovlp1_sh = 206
# Shuffle 986/1000  —  H = 17445.662298
# ovlp0_sh = 95955  ovlp1_sh = 172
# Shuffle 987/1000  —  H = 17552.513714
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 988/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 154
# Shuffle 989/1000  —  H = 17608.903257
# ovlp0_sh = 95955  ovlp1_sh = 194
# Shuffle 990/1000  —  H = 17483.422263
# ovlp0_sh = 95955  ovlp1_sh = 190
# Shuffle 991/1000  —  H = 17495.997610
# ovlp0_sh = 95955  ovlp1_sh = 174
# Shuffle 992/1000  —  H = 17546.240204
# ovlp0_sh = 95955  ovlp1_sh = 222
# Shuffle 993/1000  —  H = 17395.239131
# ovlp0_sh = 95955  ovlp1_sh = 182
# Shuffle 994/1000  —  H = 17521.130852
# ovlp0_sh = 95955  ovlp1_sh = 212
# Shuffle 995/1000  —  H = 17426.763682
# ovlp0_sh = 95955  ovlp1_sh = 192
# Shuffle 996/1000  —  H = 17489.710655
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 997/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 180
# Shuffle 998/1000  —  H = 17527.410460
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 999/1000  —  H = 17502.283118
# ovlp0_sh = 95955  ovlp1_sh = 188
# Shuffle 1000/1000  —  H = 17502.283118
# H_identity = 6706.368689725659
# H_shuffle (lista) = [17395.239130737093, 17495.99761010669, 17495.99761010669, 17477.132445496867, 17369.995824773727, 17470.841211361767, 17514.849750627476, 17495.99761010669, 17458.25453198841, 17470.841211361767, 17458.25453198841, 17414.157852831395, 17552.513714034892, 17583.857574603106, 17533.688563706673, 17502.28311843477, 17514.849750627476, 17420.46143725151, 17369.995824773727, 17521.13085167529, 17514.849750627476, 17483.422263292327, 17489.710654888655, 17552.513714034892, 17495.99761010669, 17502.28311843477, 17508.567169014983, 17558.785664873787, 17483.422263292327, 17344.73191727283, 17565.056041919903, 17539.965149460444, 17470.841211361767, 17552.513714034892, 17420.46143725151, 17376.308597439853, 17539.965149460444, 17652.666355524627, 17552.513714034892, 17395.239130737093, 17483.422263292327, 17414.157852831395, 17533.688563706673, 17407.852935599334, 17426.763681590684, 17608.903256614394, 17565.056041919903, 17502.28311843477, 17458.25453198841, 17426.763681590684, 17508.567169014983, 17433.064578362595, 17495.99761010669, 17539.965149460444, 17514.849750627476, 17458.25453198841, 17571.324829886828, 17527.41046016857, 17508.567169014983, 17495.99761010669, 17565.056041919903, 17470.841211361767, 17508.567169014983, 17590.1214978587, 17539.965149460444, 17539.965149460444, 17615.160442153385, 17338.412763960623, 17583.857574603106, 17439.36411985566, 17552.513714034892, 17495.99761010669, 17451.959104982856, 17420.46143725151, 17420.46143725151, 17596.383764989012, 17445.66229812516, 17577.592012927307, 17420.46143725151, 17552.513714034892, 17546.240204151632, 17571.324829886828, 17451.959104982856, 17533.688563706673, 17439.36411985566, 17426.763681590684, 17382.620076764804, 17521.13085167529, 17445.66229812516, 17565.056041919903, 17483.422263292327, 17445.66229812516, 17546.240204151632, 17514.849750627476, 17420.46143725151, 17439.36411985566, 17483.422263292327, 17382.620076764804, 17439.36411985566, 17439.36411985566, 17514.849750627476, 17451.959104982856, 17464.548570439605, 17445.66229812516, 17615.160442153385, 17363.681764715537, 17445.66229812516, 17433.064578362595, 17445.66229812516, 17477.132445496867, 17445.66229812516, 17414.157852831395, 17325.77068242425, 17495.99761010669, 17502.28311843477, 17502.28311843477, 17464.548570439605, 17621.415893579968, 17483.422263292327, 17546.240204151632, 17514.849750627476, 17477.132445496867, 17477.132445496867, 17583.857574603106, 17502.28311843477, 17401.546692615273, 17376.308597439853, 17558.785664873787, 17502.28311843477, 17565.056041919903, 17539.965149460444, 17495.99761010669, 17464.548570439605, 17552.513714034892, 17470.841211361767, 17539.965149460444, 17489.710654888655, 17388.930256628344, 17489.710654888655, 17439.36411985566, 17407.852935599334, 17470.841211361767, 17583.857574603106, 17596.383764989012, 17401.546692615273, 17477.132445496867, 17489.710654888655, 17477.132445496867, 17533.688563706673, 17433.064578362595, 17433.064578362595, 17445.66229812516, 17477.132445496867, 17514.849750627476, 17464.548570439605, 17596.383764989012, 17633.921507301187, 17577.592012927307, 17376.308597439853, 17451.959104982856, 17376.308597439853, 17464.548570439605, 17351.049805412767, 17640.171623958453, 17583.857574603106, 17483.422263292327, 17546.240204151632, 17458.25453198841, 17514.849750627476, 17514.849750627476, 17445.66229812516, 17521.13085167529, 17363.681764715537, 17451.959104982856, 17514.849750627476, 17458.25453198841, 17514.849750627476, 17401.546692615273, 17527.41046016857, 17477.132445496867, 17508.567169014983, 17546.240204151632, 17533.688563706673, 17369.995824773727, 17407.852935599334, 17433.064578362595, 17388.930256628344, 17495.99761010669, 17414.157852831395, 17552.513714034892, 17369.995824773727, 17552.513714034892, 17414.157852831395, 17527.41046016857, 17464.548570439605, 17495.99761010669, 17577.592012927307, 17514.849750627476, 17495.99761010669, 17514.849750627476, 17539.965149460444, 17502.283118434 ...

# %%
import matplotlib.pyplot as plt

plt.hist(H_shuffle, bins=10, density=True)
plt.axvline(H_identity)

plt.xlabel("Energia H")
plt.ylabel("Densitat")
plt.title("Distribució d'energies (shuffles) i H identitat")

plt.show()
